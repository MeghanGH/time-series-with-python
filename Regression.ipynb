# %% [markdown]
# <a href="https://colab.research.google.com/github/MeghanGH/time-series-with-python/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # import

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Creating features
#
# Dataframe to Numpy array for scikit learn

# %%
diabetes_clean = '/content/drive/My Drive/Colab Notebooks/Supervised-Learning-with-scikit-learn/data/diabetes_clean.csv'
diabetes = pd.read_csv(diabetes_clean)
diabetes.head()
# Out:
#    pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0            6      148         72       35        0  33.6  0.627   50
# 1            1       85         66       29        0  26.6  0.351   31
# 2            8      183         64        0        0  23.3  0.672   32
# 3            1       89         66       23       94  28.1  0.167   21
# 4            0      137         40       35      168  43.1  2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
X = diabetes.drop('glucose', axis=1).values # numpy.ndarray
y = diabetes['glucose'].values # numpy.ndarray

print(X[:3])
print(y[:3])
# Out:
# [[ 6.    72.    35.     0.    33.6    0.627 50.     1.   ]
#  [ 1.    66.    29.     0.    26.6    0.351 31.     0.   ]
#  [ 8.    64.     0.     0.    23.3    0.672 32.     1.   ]]
# [148  85 183]

# %%
advertising_and_sales_clean = '/content/drive/My Drive/Colab Notebooks/Supervised-Learning-with-scikit-learn/data/advertising_and_sales_clean.csv'
# sales = pd.read_csv(advertising_and_sales_clean, parse_dates=['Date'], index_col=['Date'])
sales_df = pd.read_csv(advertising_and_sales_clean)
sales_df.head(2)
# Out:
#         tv    radio  social_media influencer     sales
# 0  16000.0  6566.23       2907.98       Mega  54732.76
# 1  13000.0  9237.76       2409.57       Mega  46677.90

# %%
import numpy as np

# Create X from the radio column's values  (numpy array)
X = sales_df['radio'].values

# Create y from the sales column's values (numpy array)
y = sales_df['sales'].values

# Reshape X into two-dimensional NumPy array.

print(X.shape)
X = X.reshape(-1,1)
print(X.shape)

# Check the shape of the features and targets
print(X.shape, y.shape)
# Out:
# (4546,)
# (4546, 1)
# (4546, 1) (4546,)

# %% [markdown]
# # Building a linear regression model

# %%
from sklearn.linear_model import LinearRegression

df = sns.load_dataset('iris')
x = df[['sepal_length']] # change from single string to list of strings
y = df['sepal_width']
model = LinearRegression()
model.fit(x, y)
predictions = model.predict(x)
plt.scatter(x, y, color='blue')

plt.plot(x, predictions, color='red')
plt.xlabel("sepal_length")
plt.ylabel("sepal_width")
plt.show()

# %%
# Import LinearRegression
from sklearn.linear_model import LinearRegression

# Create the model
reg = LinearRegression()

y = sales_df["sales"].values
X = sales_df["radio"].values.reshape(-1, 1)

# Fit the model to the data
reg.fit(X, y)

# Make predictions
predictions = reg.predict(X)

print(predictions[:5])

plt.scatter(X, y, color='blue')
plt.plot(X, predictions, color='red')
plt.xlabel("Radio Expenditure ($)")
plt.ylabel("Sales ($)")
plt.show()
# Out:
# [ 95491.17119147 117829.51038393 173423.38071499 291603.11444202
#  111137.28167129]
